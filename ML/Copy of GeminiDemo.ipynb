# %%
# !pip -q install google-generativeai==0.3.0
# !pip -q install google-ai-generativelanguage==0.4.0
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.9/145.9 kB 1.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 598.7/598.7 kB 5.6 MB/s eta 0:00:00

# %%
from google.colab import userdata
userdata.get('API_KEY1')
# Out:
# 'AIzaSyATWCqz7uCC8wfdb_fWlkOMLLVhz4tWMFA'

# %%
# setup
import google.generativeai as genai
from google.colab import userdata

from IPython.display import display
from IPython.display import Markdown

GOOGLE_AI_STUDIO = userdata.get('API_KEY1')

genai.configure(api_key=GOOGLE_AI_STUDIO)

# %%
for m in genai.list_models():
    print(m.name)
    print(m.supported_generation_methods)
# Out:
# models/chat-bison-001
# ['generateMessage', 'countMessageTokens']
# models/text-bison-001
# ['generateText', 'countTextTokens', 'createTunedTextModel']
# models/embedding-gecko-001
# ['embedText', 'countTextTokens']
# models/gemini-1.0-pro-latest
# ['generateContent', 'countTokens']
# models/gemini-1.0-pro
# ['generateContent', 'countTokens']
# models/gemini-pro
# ['generateContent', 'countTokens']
# models/gemini-1.0-pro-001
# ['generateContent', 'countTokens', 'createTunedModel']
# models/gemini-1.0-pro-vision-latest
# ['generateContent', 'countTokens']
# models/gemini-pro-vision
# ['generateContent', 'countTokens']
# models/gemini-1.5-pro-latest
# ['generateContent', 'countTokens']
# models/gemini-1.5-pro-001
# ['generateContent', 'countTokens', 'createCachedContent']
# models/gemini-1.5-pro
# ['generateContent', 'countTokens']
# models/gemini-1.5-pro-exp-0801
# ['generateContent', 'countTokens']
# models/gemini-1.5-flash-latest
# ['generateContent', 'countTokens']
# models/gemini-1.5-flash-001
# ['generateContent', 'countTokens', 'createCachedContent']
# models/gemini-1.5-flash
# ['generateContent', 'countTokens']
# models/gemini-1.5-flash-001-tuning
# ['generateContent', 'countTokens', 'createTunedModel']
# models/embedding-001
# ['embedContent']
# models/text-embedding-004
# ['embedContent']
# models/aqa
# ['generateAnswer']

# %%
# Set up the model
generation_config = {
  "temperature": 0.9,
  "top_p": 1,
  "top_k": 1,
  "max_output_tokens": 2048,
}

safety_settings = [
  {
    "category": "HARM_CATEGORY_HARASSMENT",
    "threshold": "BLOCK_MEDIUM_AND_ABOVE"
  },
  {
    "category": "HARM_CATEGORY_HATE_SPEECH",
    "threshold": "BLOCK_MEDIUM_AND_ABOVE"
  },
  {
    "category": "HARM_CATEGORY_SEXUALLY_EXPLICIT",
    "threshold": "BLOCK_ONLY_HIGH"
  },
  {
    "category": "HARM_CATEGORY_DANGEROUS_CONTENT",
    "threshold": "BLOCK_ONLY_HIGH"
  }
]


model = genai.GenerativeModel(model_name="gemini-pro",
                              generation_config=generation_config,
                              safety_settings=safety_settings)


prompt_parts = [
  "Explain generative AI",
]


response = model.generate_content(prompt_parts)
print(response.text)
# Out:
# **Generative AI**
#
# Generative AI is a type of artificial intelligence that can create new data or content from scratch. It is based on machine learning algorithms that are trained on large datasets of existing data. Once trained, generative AI models can generate text, images, music, videos, and other types of content that are both unique and indistinguishable from human-generated content.
#
# **How Generative AI Works:**
#
# * **Data Acquisition:** Generative AI models are trained on vast amounts of data to learn the underlying patterns and structures. This data can include text, images, audio, or any other type of digital information.
# * **Model Training:** Machine learning algorithms are used to train the generative model on the acquired data. During training, the model learns to recognize patterns and generate new data that resembles the training data.
# * **Content Generation:** Once trained, the generative AI model can be used to generate new content by providing it with a seed or prompt. The model then uses its knowledge and learned patterns to create unique and realistic content.
#
# **Types of Generative AI:**
#
# * **Natural Language Generation (NLG):** Generates text, such as articles, stories, or scripts.
# * **Image Generation:** Creates realistic images, including landscapes, portraits, or abstract art.
# * **Music Generation:** Composes music from scratch, including melodies, harmonies, and rhythms.
# * **Video Generation:** Produces videos that resemble human-made content, such as animations, documentaries, or music videos.
# * **Code Generation:** Generates code snippets or scripts that can be used in software development.
#
# **Applications of Generative AI:**
#
# * Content creation (e.g., writing articles, designing images)
# * Data augmentation (e.g., creating synthetic data for training machine learning models)
# * Entertainment (e.g., generating music, videos)
# * Education (e.g., providing personalized learning experiences)
# * Research (e.g., discovering new materials, drugs)
#
# **Benefits of Generative AI:**
#
# * **Augmentation of Human Creativity:** Generative AI can assist humans in creating content and ideas by providing them with unique and innovative suggestions.
# * **Increased Production Efficiency:** Generative AI can automate the creation of content and data, freeing up human resources for more complex tasks.
# * **Personalized Experiences:** Generative AI can generate content tailored to individual preferences and needs.
# * **Enhancements to Existing Technologies:** Generative AI can improve the performance of existing technologies, such as language translation and image recognition.
#
# **Current Limitations and Challenges:**
#
# * **Bias:** Generative AI models can inherit biases from the data they are trained on, leading to unfair or inaccurate outcomes.
# * **Ethical Concerns:** The use of generative AI for purposes of deception or fraud raises ethical concerns about its potential impact on society.
# * **Technical Limitations:** Generative AI models require significant computing power and data to train, which can limit their accessibility and practicality.
# * **Creativity Assessment:** While generative AI can mimic human creativity, it is still being debated to what extent these creations are truly original and impactful.
